# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

color_map = sns.color_palette("light:#00700c", as_cmap=True)
color_map.set_bad('black')
sns.set(font_scale=1.2)

# %%
# Sentiment
data_imdb_vs = [[0.9,0.92,1,0.004,0.21],
                [0.87,0.87,0.91,0.0039,0.26],
                [0.17,0.78,0.42,0.0052,0.36]]
                
index_col = ['imdb_imdb', 'imdb_yelp', 'imdb_sst']
df_imdb_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_imdb_vs)


data_sst_vs = [[0.89,0.66,0.99,0.0032,0.46],
               [0.21,0.77,0.22,0.0051,0.38],
               [0.16,0.72,0.004,0.0046,0.41]]
               
index_col = ['sst_sst', 'sst_imdb', 'sst_yelp']
df_sst_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_sst_vs)


data_yelp_vs = [[0.93,0.86,0.98,0.0036,0.26],
                [0.86,0.87,0.76,0.0041,0.27],
                [0.19,0.73,0.94,0.0038,0.4]]

index_col = ['yelp_yelp', 'yelp_imdb', 'yelp_sst']
df_yelp_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_yelp_vs)

# %%
df_imdb_vs.corr()
# Out:
#              Acc    Cosine     Mauve      Wstn       JSD
# Acc     1.000000  0.948035  0.994136 -0.994441 -0.956174
# Cosine  0.948035  1.000000  0.976881 -0.909263 -0.999645
# Mauve   0.994136  0.976881  1.000000 -0.977223 -0.982229
# Wstn   -0.994441 -0.909263 -0.977223  1.000000  0.920028
# JSD    -0.956174 -0.999645 -0.982229  0.920028  1.000000

# %%
#MCQ

data_sciq_vs = [[0.64,0.82,1,0.004,0.33],
                [0.18,0.66,0.01,0.008,0.46],
                [0.34,0.78,1,0.004,0.37]]
                
index_col = ['sciq_sciq', 'sciq_qasc', 'sciq_cs']
data_sciq_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_sciq_vs)


data_cs_vs = [[0.49,0.71,0.94,0.003,0.45],
              [0.58,0.62,0.01,0.007,0.48],
              [0.84,0.61,0.004,0.005,0.49]]
               
index_col = ['cs_cs', 'cs_sciq', 'cs_qasc']
data_cs_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_cs_vs)


data_qasc_vs = [[0.92,0.75,1,0.003,0.4],
                [0.51,0.78,0.99,0.004,0.38],
                [0.48,0.66,0.004,0.006,0.48]]

index_col = ['qasc_qasc', 'qasc_sciq', 'qasc_cs']
data_qasc_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_qasc_vs)

# %%
# Extractive QA

data_squad_vs = [[0.86,0.84,0.99,0.0037,0.34],
                  [0.51,0.82,0.32,0.0041,0.33],
                  [0.56,0.81,0.04,0.0059,0.33]]
                
index_col = ['squad_squad', 'squad_trivia', 'squad_news']
data_squad_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_squad_vs)

data_news_vs = [[0.66,0.89,0.91,0.0036,0.23],
                [0.77,0.86,0.11,0.0046,0.31],
                [0.56,0.84,0.89,0.0039,0.27]]
               
index_col = ['news_news', 'news_squad', 'news_trivia']
data_news_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_news_vs)

data_trivia_vs = [[0.66,0.88,0.99,0.0031,0.23],
                  [0.52,0.82,0.04,0.0062,0.34],
                  [0.31,0.82,0.99,0.0042,0.29]]

index_col = ['trivia_trivia', 'trivia_squad', 'trivia_news']
data_trivia_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_trivia_vs)

# %%
# NLI
data_mnli_vs = [[0.57,0.72,0.97,0.0035,0.43],
                [0.56,0.71,0.27,0.0032,0.43],
                [0.54,0.73,0.99,0.0037,0.42]]
                
index_col = ['mnli_mnli', 'mnli_wnli', 'mnli_qnli']
data_mnli_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_mnli_vs)

data_wnli_vs = [[0.42,0.74,0.79,0.0032,0.41],
                [0.26,0.68,0.66,0.0036,0.46],
                [0.47,0.67,0.004,0.0035,0.46]]
               
index_col = ['wnli_wnli', 'wnli_mnli', 'wnli_qnli']
data_wnli_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_wnli_vs)

data_qnli_vs = [[0.83,0.75,0.97,0.0036,0.41],
                [0.43,0.64,0.66,0.0039,0.45],
                [0.56,0.58,0.01,0.0034,0.48]]

index_col = ['qnli_qnli', 'qnli_mnli', 'qnli_wnli']
data_qnli_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'], 
                  index=index_col,
                  data=data_qnli_vs)

# %%
df_imdb_vs.corr()[:1]
df_sst_vs.corr()[:1]
df_yelp_vs.corr()[:1]

data_sciq_vs.corr()[:1]
data_cs_vs.corr()[:1]
data_qasc_vs.corr()[:1]

data_squad_vs.corr()[:1]
data_news_vs.corr()[:1]
data_trivia_vs.corr()[:1]

data_mnli_vs.corr()[:1]
data_wnli_vs.corr()[:1]
data_qnli_vs.corr()[:1]
# Out:
#      Acc    Cosine     Mauve     Wstn       JSD
# Acc  1.0  0.777821  0.497998 -0.42519 -0.721024

# %%
lst = [df_imdb_vs.corr()[:1].values.tolist()[0],
       df_sst_vs.corr()[:1].values.tolist()[0],
       df_yelp_vs.corr()[:1].values.tolist()[0],
       data_sciq_vs.corr()[:1].values.tolist()[0],
       data_cs_vs.corr()[:1].values.tolist()[0],
       data_qasc_vs.corr()[:1].values.tolist()[0],
       data_squad_vs.corr()[:1].values.tolist()[0],
       data_news_vs.corr()[:1].values.tolist()[0],
       data_trivia_vs.corr()[:1].values.tolist()[0],
       data_mnli_vs.corr()[:1].values.tolist()[0],
       data_wnli_vs.corr()[:1].values.tolist()[0],
       data_qnli_vs.corr()[:1].values.tolist()[0]]
    
df = pd.DataFrame(lst, 
                  columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'],
                  index=['imdb', 'sst', 'yelp', 'sciq', 'cs', 'qasc', 'squad', 'news', 'trivia', 'mnli', 'wnli', 'qnli'])
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD
# imdb    1.0  0.948035  0.994136 -0.994441 -0.956174
# sst     1.0 -0.861539  0.988983 -0.949866  0.904071
# yelp    1.0  0.988795 -0.263181  0.029179 -0.999764
# sciq    1.0  0.898272  0.766426 -0.766426 -0.923974
# cs      1.0 -0.760902 -0.702826  0.247592  0.850196
# qasc    1.0  0.335457  0.559177 -0.794466 -0.384373
# squad   1.0  0.893405  0.911726 -0.533428  0.991241
# news    1.0  0.371990 -0.868794  0.701889  0.523612
# trivia  1.0  0.802955 -0.114708 -0.240192 -0.444912
# mnli    1.0 -0.654654 -0.212874 -0.563621  0.944911
# wnli    1.0  0.160525 -0.563505 -0.510908 -0.289474
# qnli    1.0  0.777821  0.497998 -0.425190 -0.721024

# %%
sns.heatmap(df.iloc[:, 1:], vmin=-1, vmax=1, annot=True, cmap=color_map, cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# 5/5
#
# 2/5
#
# 3/5
# 4/5
# 0/5
# 2/5
# 3/5
# 0/5
# 1/5
# 0/5
# 0/5
# 3/5

# %% [markdown]
# ## Kendall

# %%
lst = [df_imdb_vs.corr(method='kendall')[:1].values.tolist()[0], 
       df_sst_vs.corr(method='kendall')[:1].values.tolist()[0],
       df_yelp_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_sciq_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_cs_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_qasc_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_squad_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_news_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_trivia_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_mnli_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_wnli_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_qnli_vs.corr(method='kendall')[:1].values.tolist()[0]
       ]
    
df = pd.DataFrame(lst, 
                  columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'],
                  index=['imdb', 'sst', 'yelp', 'sciq', 'cs', 'qasc', 'squad', 'news', 'trivia', 'mnli', 'wnli', 'qnli'])
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD
# imdb    1.0  1.000000  1.000000 -0.333333 -1.000000
# sst     1.0 -0.333333  1.000000 -0.333333  0.333333
# yelp    1.0  0.333333  0.333333 -0.333333 -1.000000
# sciq    1.0  1.000000  0.816497 -0.816497 -1.000000
# cs      1.0 -1.000000 -1.000000  0.333333  1.000000
# qasc    1.0  0.333333  1.000000 -1.000000 -0.333333
# squad   1.0  0.333333  0.333333 -0.333333  0.816497
# news    1.0  0.333333 -0.333333  0.333333  0.333333
# trivia  1.0  0.816497  0.000000 -0.333333 -0.333333
# mnli    1.0 -0.333333 -0.333333 -0.333333  0.816497
# wnli    1.0 -0.333333 -0.333333 -0.333333  0.000000
# qnli    1.0  0.333333  0.333333 -0.333333 -0.333333

# %%
sns.heatmap(df.iloc[:, 1:], vmin=-1, vmax=1, annot=True, cmap=color_map, cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# ##Spearman

# %%
lst = [df_imdb_vs.corr(method='spearman')[:1].values.tolist()[0], 
       df_sst_vs.corr(method='spearman')[:1].values.tolist()[0],
       df_yelp_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_sciq_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_cs_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_qasc_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_squad_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_news_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_trivia_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_mnli_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_wnli_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_qnli_vs.corr(method='spearman')[:1].values.tolist()[0]
       ]
    
df = pd.DataFrame(lst, 
                  columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD'],
                  index=['imdb', 'sst', 'yelp', 'sciq', 'cs', 'qasc', 'squad', 'news', 'trivia', 'mnli', 'wnli', 'qnli'])
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD
# imdb    1.0  1.000000  1.000000 -0.500000 -1.000000
# sst     1.0 -0.500000  1.000000 -0.500000  0.500000
# yelp    1.0  0.500000  0.500000 -0.500000 -1.000000
# sciq    1.0  1.000000  0.866025 -0.866025 -1.000000
# cs      1.0 -1.000000 -1.000000  0.500000  1.000000
# qasc    1.0  0.500000  1.000000 -1.000000 -0.500000
# squad   1.0  0.500000  0.500000 -0.500000  0.866025
# news    1.0  0.500000 -0.500000  0.500000  0.500000
# trivia  1.0  0.866025  0.000000 -0.500000 -0.500000
# mnli    1.0 -0.500000 -0.500000 -0.500000  0.866025
# wnli    1.0 -0.500000 -0.500000 -0.500000  0.000000
# qnli    1.0  0.500000  0.500000 -0.500000 -0.500000

# %%
sns.heatmap(df, vmin=-1, vmax=1, annot=True, cmap=color_map, cbar=False)
