# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

color_map = sns.color_palette("light:#00700c", as_cmap=True)
color_map.set_bad('black')
sns.set(font_scale=1.2)

# %%
# Sentiment
data_imdb_vs = [[0.9,0.84,0.991,0.0014,0.007, -1.40E+18],
                [0.87,0.77,0.004,0.0015,0.008, -6.50E+17],
                [0.17,0.74,0.032,0.0015,0.009, -1.02E+18]]
                
index_col = ['imdb_imdb', 'imdb_yelp', 'imdb_sst']
df_imdb_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_imdb_vs)


data_sst_vs = [[0.89,0.73,0.998,0.0016,0.009, 3.50E+18],
[0.21,0.75,0.004,0.0014,0.008, 5.51E+18],
[0.16,0.7,0.004,0.0016,0.009, 4.30E+18]]
               
index_col = ['sst_sst', 'sst_imdb', 'sst_yelp']
df_sst_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_sst_vs)


data_yelp_vs = [[0.93,0.81,0.992,0.0013,0.007, 3.14E+17],
[0.86,0.76,0.004,0.0016,0.008, 9.00E+17],
[0.19,0.7,0.01,0.0016,0.009, 6.27E+17]]

index_col = ['yelp_yelp', 'yelp_imdb', 'yelp_sst']
df_yelp_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_yelp_vs)

# %%
#MCQ

data_sciq_vs = [[0.64,0.76,1,0.0015,0.0086, 5.31E+18],
[0.18,0.75,0.75,0.0016,0.0089, 3.21E+18],
[0.34,0.71,0.04,0.0016,0.0096, 7.69E+18]]
                
index_col = ['sciq_sciq', 'sciq_qasc', 'sciq_cs']
data_sciq_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_sciq_vs)


data_cs_vs = [[0.49,0.72,0.99,0.0014,0.0093, -4.62E+18],
[0.58,0.71,0.04,0.0016,0.0096, -3.45E+18],
[0.84,0.71,0.95,0.0016,0.0095, -3.24E+18]]
               
index_col = ['cs_cs', 'cs_sciq', 'cs_qasc']
data_cs_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_cs_vs)


data_qasc_vs = [[0.92,0.74,0.99,0.0017,0.0089, 4.58E+17],
[0.51,0.75,0.99,0.0016,0.0089, 3.38E+17],
[0.48,0.71,0.15,0.0016,0.0095, 4.44E+17]]

index_col = ['qasc_qasc', 'qasc_sciq', 'qasc_cs']
data_qasc_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_qasc_vs)

# %%
# Extractive QA

data_squad_vs = [[0.86,0.77,0.99,0.0015,0.0085, -6.41E+17],
                 [0.51,0.78,0.17,0.0014,0.0083, -4.47E+17],
                 [0.55,0.78,0.88,0.0015,0.0083, -9.47E+17]]
                
index_col = ['squad_squad', 'squad_trivia', 'squad_news']
data_squad_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_squad_vs)

data_news_vs = [[0.66,0.81,0.97,0.0014,0.0076, -4.62E+18],
[0.77,0.77,0.04,0.0015,0.0086, -4.95E+18],
[0.57,0.79,0.34,0.0015,0.0081, -6.55E+18]]
               
index_col = ['news_news', 'news_squad', 'news_trivia']
data_news_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_news_vs)

data_trivia_vs = [[0.66,0.8,0.99,0.0015,0.0078, -3.87E+16],
[0.52,0.78,0.98,0.0015,0.0084, -2.96E+17],
[0.31,0.8,0.17,0.0014,0.0079, -5.67E+17]]

index_col = ['trivia_trivia', 'trivia_squad', 'trivia_news']
data_trivia_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_trivia_vs)

# %%
# NLI
data_mnli_vs = [[0.57,0.69,0.99,0.0016,0.0099, -5.20E+17],
[0.56,0.68,0.32,0.0016,0.01, -7.89E+17],
[0.54,0.7,0.89,0.0017,0.0097, -8.59E+16]]
                
index_col = ['mnli_mnli', 'mnli_wnli', 'mnli_qnli']
data_mnli_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_mnli_vs)

data_wnli_vs = [[0.42,0.7,0.89,0.0015,0.0097, -4.62E+18],
[0.26,0.69,0.94,0.0016,0.0099, -3.16E+18],
[0.47,0.7,0.34,0.0015,0.0098, -6.91E+18]]
               
index_col = ['wnli_wnli', 'wnli_mnli', 'wnli_qnli']
data_wnli_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_wnli_vs)

data_qnli_vs = [[0.83,0.72,0.99,0.0016,0.0094, 2.42E+18],
[0.43,0.69,0.27,0.0015,0.0099, 2.93E+18],
[0.56,0.68,0.07,0.0016,0.01, 1.51E+18]]

index_col = ['qnli_qnli', 'qnli_mnli', 'qnli_wnli']
data_qnli_vs = pd.DataFrame(columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'], 
                  index=index_col,
                  data=data_qnli_vs)

# %%
df_imdb_vs.corr()[:1]
df_sst_vs.corr()[:1]
df_yelp_vs.corr()[:1]

data_sciq_vs.corr()[:1]
data_cs_vs.corr()[:1]
data_qasc_vs.corr()[:1]

data_squad_vs.corr()[:1]
data_news_vs.corr()[:1]
data_trivia_vs.corr()[:1]

data_mnli_vs.corr()[:1]
data_wnli_vs.corr()[:1]
data_qnli_vs.corr()[:1]
# Out:
#      Acc    Cosine     Mauve      Wstn       JSD      Maha
# Acc  1.0  0.843637  0.861603  0.749833 -0.886816 -0.162268

# %%
lst = [df_imdb_vs.corr()[:1].values.tolist()[0], 
       df_sst_vs.corr()[:1].values.tolist()[0],
       df_yelp_vs.corr()[:1].values.tolist()[0],
       data_sciq_vs.corr()[:1].values.tolist()[0],
       data_cs_vs.corr()[:1].values.tolist()[0],
       data_qasc_vs.corr()[:1].values.tolist()[0],
       data_squad_vs.corr()[:1].values.tolist()[0],
       data_news_vs.corr()[:1].values.tolist()[0],
       data_trivia_vs.corr()[:1].values.tolist()[0],
       data_mnli_vs.corr()[:1].values.tolist()[0],
       data_wnli_vs.corr()[:1].values.tolist()[0],
       data_qnli_vs.corr()[:1].values.tolist()[0]]
    
df = pd.DataFrame(lst, 
                  columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'],
                  index=['imdb', 'sst', 'yelp', 'sciq', 'cs', 'qasc', 'squad', 'news', 'trivia', 'mnli', 'wnli', 'qnli'])
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD      Maha
# imdb    1.0  0.755592  0.509844 -0.531118 -0.883611 -0.044004
# sst     1.0  0.175392  0.998119  0.445968  0.445968 -0.763442
# yelp    1.0  0.926654  0.568022 -0.572356 -0.905677 -0.124840
# sciq    1.0  0.356076  0.414726 -0.939490 -0.453401  0.308476
# cs      1.0 -0.698853  0.233984  0.698853  0.426229  0.792853
# qasc    1.0  0.335457  0.551911  0.998137 -0.551911  0.539152
# squad   1.0 -0.994535  0.683157  0.587680  0.994535  0.024021
# news    1.0 -0.549086 -0.370177  0.057639  0.549086  0.737256
# trivia  1.0 -0.114708  0.921833  0.917663 -0.041204  0.995005
# mnli    1.0 -0.654654 -0.051319 -0.944911  0.785714 -0.750273
# wnli    1.0  0.973684 -0.737043 -0.973684 -0.729285 -0.912773
# qnli    1.0  0.843637  0.861603  0.749833 -0.886816 -0.162268

# %%
sns.heatmap(df.iloc[:, 1:5], vmin=-1, vmax=1, annot=True, cmap=color_map, cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# 5/5
#
# 2/5
#
# 3/5
# 4/5
# 0/5
# 2/5
# 3/5
# 0/5
# 1/5
# 0/5
# 0/5
# 3/5

# %% [markdown]
# ## Kendall

# %%
lst = [df_imdb_vs.corr(method='kendall')[:1].values.tolist()[0], 
       df_sst_vs.corr(method='kendall')[:1].values.tolist()[0],
       df_yelp_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_sciq_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_cs_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_qasc_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_squad_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_news_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_trivia_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_mnli_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_wnli_vs.corr(method='kendall')[:1].values.tolist()[0],
       data_qnli_vs.corr(method='kendall')[:1].values.tolist()[0]
       ]
    
df = pd.DataFrame(lst, 
                  columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'],
                  index=['imdb', 'sst', 'yelp', 'sciq', 'cs', 'qasc', 'squad', 'news', 'trivia', 'mnli', 'wnli', 'qnli'])
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD      Maha
# imdb    1.0  1.000000  0.333333 -0.816497 -1.000000 -0.333333
# sst     1.0  0.333333  0.816497  0.000000  0.000000 -0.333333
# yelp    1.0  1.000000  0.333333 -0.816497 -1.000000 -0.333333
# sciq    1.0  0.333333  0.333333 -0.816497 -0.333333  0.333333
# cs      1.0 -0.816497 -0.333333  0.816497  0.333333  1.000000
# qasc    1.0  0.333333  0.816497  0.816497 -0.816497  0.333333
# squad   1.0 -0.816497  1.000000  0.816497  0.816497 -0.333333
# news    1.0 -0.333333 -0.333333  0.000000  0.333333  0.333333
# trivia  1.0  0.000000  1.000000  0.816497 -0.333333  1.000000
# mnli    1.0 -0.333333  0.333333 -0.816497  0.333333 -0.333333
# wnli    1.0  0.816497 -1.000000 -0.816497 -0.333333 -1.000000
# qnli    1.0  0.333333  0.333333  0.816497 -0.333333 -0.333333

# %%
sns.heatmap(df.iloc[:, 1:5], vmin=-1, vmax=1, annot=True, cmap=color_map, cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ##Spearman

# %%
lst = [df_imdb_vs.corr(method='spearman')[:1].values.tolist()[0], 
       df_sst_vs.corr(method='spearman')[:1].values.tolist()[0],
       df_yelp_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_sciq_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_cs_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_qasc_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_squad_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_news_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_trivia_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_mnli_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_wnli_vs.corr(method='spearman')[:1].values.tolist()[0],
       data_qnli_vs.corr(method='spearman')[:1].values.tolist()[0]
       ]
    
df = pd.DataFrame(lst, 
                  columns=['Acc', 'Cosine', 'Mauve', 'Wstn', 'JSD', 'Maha'],
                  index=['imdb', 'sst', 'yelp', 'sciq', 'cs', 'qasc', 'squad', 'news', 'trivia', 'mnli', 'wnli', 'qnli'])
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD  Maha
# imdb    1.0  1.000000  0.500000 -0.866025 -1.000000  -0.5
# sst     1.0  0.500000  0.866025  0.000000  0.000000  -0.5
# yelp    1.0  1.000000  0.500000 -0.866025 -1.000000  -0.5
# sciq    1.0  0.500000  0.500000 -0.866025 -0.500000   0.5
# cs      1.0 -0.866025 -0.500000  0.866025  0.500000   1.0
# qasc    1.0  0.500000  0.866025  0.866025 -0.866025   0.5
# squad   1.0 -0.866025  1.000000  0.866025  0.866025  -0.5
# news    1.0 -0.500000 -0.500000  0.000000  0.500000   0.5
# trivia  1.0  0.000000  1.000000  0.866025 -0.500000   1.0
# mnli    1.0 -0.500000  0.500000 -0.866025  0.500000  -0.5
# wnli    1.0  0.866025 -1.000000 -0.866025 -0.500000  -1.0
# qnli    1.0  0.500000  0.500000  0.866025 -0.500000  -0.5

# %%
df
# Out:
#         Acc    Cosine     Mauve      Wstn       JSD  Maha
# imdb    1.0  1.000000  0.500000 -0.866025 -1.000000  -0.5
# sst     1.0  0.500000  0.866025  0.000000  0.000000  -0.5
# yelp    1.0  1.000000  0.500000 -0.866025 -1.000000  -0.5
# sciq    1.0  0.500000  0.500000 -0.866025 -0.500000   0.5
# cs      1.0 -0.866025 -0.500000  0.866025  0.500000   1.0
# qasc    1.0  0.500000  0.866025  0.866025 -0.866025   0.5
# squad   1.0 -0.866025  1.000000  0.866025  0.866025  -0.5
# news    1.0 -0.500000 -0.500000  0.000000  0.500000   0.5
# trivia  1.0  0.000000  1.000000  0.866025 -0.500000   1.0
# mnli    1.0 -0.500000  0.500000 -0.866025  0.500000  -0.5
# wnli    1.0  0.866025 -1.000000 -0.866025 -0.500000  -1.0
# qnli    1.0  0.500000  0.500000  0.866025 -0.500000  -0.5

# %%
sns.heatmap(df.iloc[:, 1:5], vmin=-1, vmax=1, annot=True, cmap=color_map, cbar=False)
# Out:
# <Axes: >
